# %%
import os
import pandas as pd

CSV_PATH = os.path.realpath(os.path.join(os.getcwd(), "data.csv"))
df = pd.read_csv(CSV_PATH)
df.head(20)
# Out:
#                                                    id             freq  \
# 0                                                   1   50|80|60|90|70
# 1                                                   2  80|100|50|60|90
# 2                                                   3  50|70|40|90|100
# 3                                                   5  50|70|60|100|40
# 4                                                   6  100|80|90|40|70
# 5                                                   7  50|60|40|70|100
# 6               ERROR: extra parameter: "Bo".  Usage:              NaN
# 7   .output ?FILE?           Send output to FILE o...              NaN
# 8      If FILE begins with '|' then open it as a p...              NaN
# 9                                            Options:              NaN
# 10       --bom                 Prefix output with ...              NaN
# 11       -e                    Send output to the ...              NaN
# ...
